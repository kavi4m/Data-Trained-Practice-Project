# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('winequality.red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
df.quality.value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# # Removing duplicates

# %%
print("Rows, columns: " + str(df.shape)) 
df.dropna(inplace=True)
df.drop_duplicates()
# Out:
# Rows, columns: (1599, 12)
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 5               7.4             0.660         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 1593            6.8             0.620         0.08             1.9      0.068
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# # Handle Missing value

# %%
print(df.isna().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# # DATA Visualizations

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# # Outlier Treatment

# %% [markdown]
#  #histogram

# %%
df.hist(bins=10,figsize=(10,20))  #histogram
plt.show()
df.plot(kind='density',subplots=True, layout=(10,20),sharex=False)
plt.show()

# %% [markdown]
# Data Distribution Alcohol is positively skewed, For Density data is normally distributed, Wine qaulity is bimodal distributed

# %% [markdown]
# # Correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
# goodquality                0.120061         -0.270712     0.214716
#
# ...

# %%
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %%
corr = df.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
sns.color_palatte?
# Out:
# Object `sns.color_palatte` not found.

# %%
sns.heatmap?

# %%
plt.figure(figsize=(6,4))
sns.heatmap(dfcor,cmap='Blues',annot=True)
# Out:
# <AxesSubplot:>

# %%
sm=pd.plotting.scatter_matrix(df,figsize=(15,20),diagonal='kde')
[s.xaxis.label.set_rotation(40) for s in sm.reshape(-1)]
[s.yaxis.label.set_rotation(0) for s in sm.reshape(-1)]
[s.get_yaxis().set_label_coords(-0.6,0.5)for s in sm.reshape(-1)]
[s.set_xticks(()) for s in sm.reshape(-1)] #hide all ticks
[s.set_yticks(()) for s in sm.reshape(-1)]
plt.show()

# %%
df['goodquality'] = [1 if x >= 7 else 0 for x in df['quality']]
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
X = df.drop(['quality','goodquality'], axis = 1)
y = df['goodquality']

# %%
df['goodquality'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: goodquality, dtype: int64

# %%
X_features = X # Normalizing feature variables
X = StandardScaler().fit_transform(X) 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state=0) #data split

# %% [markdown]
# # DecisionTreeClassifier

# %%
model1 = DecisionTreeClassifier(random_state=1) #Decision Tree Model
model1.fit(X_train, y_train)
y_pred1 = model1.predict(X_test)
print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.92      0.94       355
#            1       0.53      0.73      0.62        45
#
#     accuracy                           0.90       400
#    macro avg       0.75      0.83      0.78       400
# weighted avg       0.92      0.90      0.90       400

# %% [markdown]
# # RandomForestClassifier

# %%
model2 = RandomForestClassifier(random_state=1) #Random Forest Model
model2.fit(X_train, y_train)
y_pred2 = model2.predict(X_test)
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       355
#            1       0.68      0.58      0.63        45
#
#     accuracy                           0.92       400
#    macro avg       0.82      0.77      0.79       400
# weighted avg       0.92      0.92      0.92       400

# %% [markdown]
# # AdaBoostClassifier

# %%
model3 = AdaBoostClassifier(random_state=1) #AdaBoost Model
model3.fit(X_train, y_train)
y_pred3 = model3.predict(X_test)
print(classification_report(y_test, y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       355
#            1       0.51      0.49      0.50        45
#
#     accuracy                           0.89       400
#    macro avg       0.72      0.71      0.72       400
# weighted avg       0.89      0.89      0.89       400

# %% [markdown]
# # GradientBoostingClassifier

# %%
model4 = GradientBoostingClassifier(random_state=1) #gradientBoosting Model
model4.fit(X_train, y_train)
y_pred4 = model4.predict(X_test)
print(classification_report(y_test, y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.94      0.94       355
#            1       0.52      0.51      0.52        45
#
#     accuracy                           0.89       400
#    macro avg       0.73      0.73      0.73       400
# weighted avg       0.89      0.89      0.89       400

# %% [markdown]
# # by looking at the above classifiers when can conclude that the Random Forest Model has the highest accuracy

# %%
df_temp2 = df[df['goodquality']==1]
df_temp2.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count     217.000000        217.000000   217.000000      217.000000
# mean        8.847005          0.405530     0.376498        2.708756
# std         1.999977          0.144963     0.194438        1.363026
# min         4.900000          0.120000     0.000000        1.200000
# 25%         7.400000          0.300000     0.300000        2.000000
# 50%         8.700000          0.370000     0.400000        2.300000
# 75%        10.100000          0.490000     0.490000        2.700000
# max        15.600000          0.915000     0.760000        8.900000
#
#         chlorides  free sulfur dioxide  total sulfur dioxide     density  \
# count  217.000000           217.000000            217.000000  217.000000
# mean     0.075912            13.981567             34.889401    0.996030
# std      0.028480            10.234615             32.572238    0.002201
# ...

# %%
df_temp = df[df['goodquality']==0]
df_temp.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1382.000000       1382.000000  1382.000000     1382.000000
# mean        8.236831          0.547022     0.254407        2.512120
# std         1.682726          0.176337     0.189665        1.415778
# min         4.600000          0.160000     0.000000        0.900000
# 25%         7.100000          0.420000     0.082500        1.900000
# 50%         7.800000          0.540000     0.240000        2.200000
# 75%         9.100000          0.650000     0.400000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1382.000000          1382.000000           1382.000000  1382.000000
# mean      0.089281            16.172214             48.285818     0.996859
# std       0.049113            10.467685             32.585604     0.001808
# ...

# %% [markdown]
# # By looking into above analysis, we can see that good quality wines have higher levels of alcohol on average, have a lower volatile acidity on average, higher levels of sulphates on average, and higher levels of residual sugar on average.
