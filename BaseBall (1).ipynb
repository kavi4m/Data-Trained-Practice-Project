# %% [markdown]
# # Importing the Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('BaseBall.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# # Checking Null Values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# # DataFrame Description

# %% [markdown]
# The datset contains the data of the baseball score at different rates according to the game is played.The dataset cosists of columns like Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, and Errors.

# %% [markdown]
# So we are going find out ouput prediction as number of Wins according to the given input features.wheather the number of wins got by the runs,average runs and other feautures.

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Checking the datatypes of the columns

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
df['W'].value_counts()
# Out:
# 68     3
# 81     2
# 74     2
# 76     2
# 83     2
# 80     1
# 97     1
# 98     1
# 67     1
# 71     1
# 78     1
# 79     1
# 95     1
# 100    1
# 92     1
# 84     1
# 85     1
# 86     1
# 87     1
# 88     1
# 90     1
# 63     1
# 93     1
# 64     1
# Name: W, dtype: int64

# %% [markdown]
# # Statistical Analysis

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# # Data Visualization

# %%
df['W'].value_counts()
# Out:
# 68     3
# 81     2
# 74     2
# 76     2
# 83     2
# 80     1
# 97     1
# 98     1
# 67     1
# 71     1
# 78     1
# 79     1
# 95     1
# 100    1
# 92     1
# 84     1
# 85     1
# 86     1
# 87     1
# 88     1
# 90     1
# 63     1
# 93     1
# 64     1
# Name: W, dtype: int64

# %%
sns.countplot(df['W'])
plt.show()

# %%
plt.subplots(figsize=(14,14))
sns.countplot(x='W',hue='R',data=df)
plt.show()

# %% [markdown]
# # Data Correlation

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(),annot=True,fmt='.0%')
plt.show()

# %%
sns.countplot(x ='W',data=df)
plt.show()

# %%
sns.pairplot(df)

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
sns.histplot(df['W'])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Count'>

# %%
sns.histplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Count'>

# %%
sns.histplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Count'>

# %%
columns= ['W','R','E','SV','ER','CG']  

for i in  df[columns]:
    plt.figure()
    sns.distplot(df[i])

# %% [markdown]
# # Outliers

# %%
fig, axs = plt.subplots(3, figsize = (5,5))
plt1 = sns.boxplot(df['W'], ax = axs[0])
plt2 = sns.boxplot(df['R'], ax = axs[1])
plt3 = sns.boxplot(df['E'], ax = axs[2])
plt.tight_layout()

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.36540860e+00, 6.19077968e-01, 8.47731264e-01, 1.66368512e+00,
#         1.42017307e+00, 1.04119304e+00, 7.87298598e-01, 1.53490242e+00,
#         2.69762957e+00, 9.13883291e-01, 6.66233927e-01, 5.05110079e-01,
#         5.06955186e-01, 5.39806195e-01, 8.14628593e-01, 1.67160651e+00,
#         4.61469635e-01],
#        [1.97838300e-01, 1.34431656e-01, 7.11093535e-01, 9.70680764e-01,
#         1.27403389e-01, 1.23580856e+00, 2.43966683e-01, 5.36591904e-01,
#         1.54878442e-01, 6.01825582e-01, 1.65970766e-01, 2.48929848e-01,
#         2.54597523e-01, 5.39806195e-01, 1.72800005e-01, 2.49879323e-01,
#         6.07196888e-01],
#        [3.24325082e-03, 3.32905860e-01, 1.11523330e+00, 1.51891367e-01,
#         1.58879521e+00, 2.23807850e-01, 7.23377196e-01, 1.13914361e+00,
#         8.93981893e-01, 1.11449182e-01, 6.80339091e-01, 7.51623132e-01,
#         6.41346840e-01, 2.77264091e+00, 3.20914294e-01, 6.54856158e-01,
#         1.11724227e+00],
# ...

# %%
z[20][3]
# Out:
# 0.9350812250657233

# %%
z[14][2]
# Out:
# 1.2085703374367176

# %%
print("shape before removing the outliers :",df.shape)
dfnew=df[(z<3).all(axis=1)]
         
print("shape after removing the outliers:",dfnew.shape)
# Out:
# shape before removing the outliers : (30, 17)
# shape after removing the outliers: (29, 17)

# %%
df=dfnew

# %%
df_x=df.drop(columns=['W'])
y=df[["W"]]

# %%
for i in df_x.columns:
    if df_x[i].skew()>0.5:
        df_x[i]=np.cbrt(df_x[i])
    if df_x[i].skew()<0.5:
        df_x[i]=np.cbrt(df_x[i])
        
df_x.skew()
# Out:
# R     -0.329729
# AB     0.155301
# H      0.753696
# 2B    -0.423788
# 3B    -0.300967
# HR     0.093886
# BB     0.008882
# SO    -0.498255
# SB     0.079220
# RA    -0.166248
# ER    -0.201289
# ERA   -0.226238
# CG    -2.420630
# SHO   -0.583531
# SV     0.158994
# E      0.671748
# dtype: float64

# %%
columns=['R','SO','ER','ERA','CG',]

for i in df_x[columns]:
    plt.figure()
    sns.distplot(df_x[i])

# %%
df_x
# Out:
#            R         AB          H        2B        3B        HR        BB  \
# 0   8.979377  17.731615  11.439506  6.694330  3.476027  5.180101  7.262167
# 1   8.862095  17.616367  11.049365  6.518684  3.530348  5.383213  7.600139
# 2   8.745985  17.586241  11.173556  6.716570  3.072317  5.204828  8.107913
# 3   8.536178  17.686975  11.136051  6.382504  3.000000  5.142563  7.392542
# 4   8.832285  17.763364  11.485173  6.611489  3.659306  5.325074  7.691372
# 6   9.141787  17.723129  11.178893  6.479224  2.668402  5.962732  8.213027
# 7   8.933669  17.635680  11.106405  6.265827  2.714418  6.009245  7.476966
# 8   8.635655  17.635680  11.141425  6.526519  3.174802  5.506878  7.582787
# 9   9.077520  17.800261  11.434409  6.649400  3.207534  5.440122  7.818846
# 10  9.089639  17.663502  11.237270  6.534335  3.174802  5.561298  7.952848
# 11  9.000000  17.607770  11.087457  6.526519  2.962496  6.126926  7.862224
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.955349  0.831930  1.728647  1.516814  0.991728 -0.748317 -1.597714
# 1   0.348400 -0.701120 -0.946162  0.219417  1.147374 -0.124429 -0.465877
# 2  -0.252490 -1.101868 -0.094708  1.681091 -0.165004 -0.672366  1.234617
# 3  -1.338270  0.238116 -0.351839 -0.786466 -0.372210 -0.863622 -1.161101
# 4   0.194128  1.254258  2.041742  0.904917  1.516870 -0.303011 -0.160345
# 5   1.795850  0.719053 -0.058116 -0.072055 -1.322324  1.655659  1.586636
# 6   0.718804 -0.444218 -0.555092 -1.648300 -1.190476  1.798531 -0.878370
# 7  -0.823461 -0.444218 -0.315000  0.277289  0.128643  0.255431 -0.523987
# 8   1.463254  1.745075  1.693704  1.184942  0.222429  0.050377  0.266555
# 9   1.525975 -0.074128  0.342114  0.335023  0.128643  0.422589  0.715317
# 10  1.062078 -0.815480 -0.685001  0.277289 -0.479668  2.160006  0.411826
# 11 -0.433630 -1.417708 -1.284608 -1.837209 -1.062954  0.553997 -0.543417
# ...

# %%
x.shape
# Out:
# (29, 16)

# %%
y.shape
# Out:
# (29, 1)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=43)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (22, 16)
# (7, 16)
# (22, 1)
# (7, 1)

# %%
x=df.iloc[:,1:df.shape[1]].values
y=df.iloc[:,0].values

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression(normalize=True)
lr.fit(x_train,y_train)
# Out:
# LinearRegression(normalize=True)

# %%
lr_pred=lr.predict(x_test)

# %%
lr_pred
# Out:
# array([[ 85.92587133],
#        [ 67.54251679],
#        [121.56798982],
#        [ 84.12640709],
#        [ 67.49639883],
#        [100.51907361],
#        [ 75.49493083]])

# %%
lr_accuracy=round(lr.score(x_train,y_train)*100)
lr_accuracy
# Out:
# 99

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, lr_pred)
# Out:
# 16.67910753292493

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, lr_pred)
# Out:
# 537.3618875280542

# %%
print("RMSE VALUE = ",mean_squared_error(y_test, lr_pred,squared = False))
# Out:
# RMSE VALUE =  23.181067437200863

# %%
import numpy as np
o = np.array(y_test)

# %%
print("original average win  is " ,o[0])
print("predicted average win is " , lr_pred[0])
# Out:
# original average win  is  [92]
# predicted average win is  [85.92587133]

# %% [markdown]
# # Saving the best model

# %% [markdown]
# # Conclusion:

# %%
import pickle

filename='pickledfile3.pkl'
pickle.dump(lr,open(filename,'wb'))

#load the model from disk
loaded_model=pickle.load(open(filename,'rb'))
loaded_model.predict(x_test)
# Out:
# array([[ 85.92587133],
#        [ 67.54251679],
#        [121.56798982],
#        [ 84.12640709],
#        [ 67.49639883],
#        [100.51907361],
#        [ 75.49493083]])
