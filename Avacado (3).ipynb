# %% [markdown]
# # Importing the Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Avacodo.csv')
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0             0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1             1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2             2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3             3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4             4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 16463         NaN         NaN           NaN           NaN      NaN        NaN
# 16464         NaN         NaN           NaN           NaN      NaN        NaN
# 16465         NaN         NaN           NaN           NaN      NaN        NaN
# 16466         NaN         NaN           NaN           NaN      NaN        NaN
# 16467         NaN         NaN           NaN           NaN      NaN        NaN
#
# ...

# %%
df.tail(50)
# Out:
#        Unnamed: 0 Date  AveragePrice  Total Volume  4046  4225  4770  \
# 16418         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16419         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16420         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16421         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16422         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16423         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16424         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16425         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16426         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16427         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16428         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16429         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16430         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# ...

# %% [markdown]
# # DataFrame Description

# %% [markdown]
# The datset contains the data of Avacado fruit and its quality in type,its cost and according to the variety the cost also varies.We are going to predict the average price of the avacado according to the given data.
#
# The dataset contains columns like AveragePrice,Total Volume,the prodcut look upcodes,region it comes from and the type of avacados wheather it is oragnic plantation or conventional type also the region the fruit we get,the sold out sizes of the bag are also given with prices accordingly.

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# # Checking the datatypes of the columns

# %%
df.dtypes
# Out:
# Unnamed: 0      float64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year            float64
# region           object
# dtype: object

# %%
df['AveragePrice'].unique()
# Out:
# array([1.33, 1.35, 0.93, 1.08, 1.28, 1.26, 0.99, 0.98, 1.02, 1.07, 1.12,
#        1.31, 1.11, 1.34, 1.45, 1.05, 1.37, 1.27, 1.32, 1.23, 1.19, 1.43,
#        1.2 , 1.22, 1.13, 1.16, 1.06, 1.17, 1.24, 0.96, 1.  , 1.09, 0.95,
#        0.97, 1.15, 1.01, 1.14, 1.1 , 1.04, 1.18, 1.29, 1.25, 1.03, 1.39,
#        1.4 , 1.36, 1.3 , 0.88, 1.21, 0.9 , 0.94, 0.75, 0.77, 0.81, 0.8 ,
#        0.72, 0.79, 0.67, 0.82, 0.68, 0.76, 0.91, 1.38, 0.92, 0.78, 0.74,
#        0.62, 0.83, 0.87, 0.73, 0.7 , 0.89, 0.85, 1.44, 1.42, 1.41, 0.49,
#        0.53, 0.66, 0.56, 0.6 , 0.71, 0.65, 0.58, 0.54, 0.52, 0.51, 0.57,
#        0.63, 0.64, 0.61, 0.84, 0.86, 0.69, 1.52, 1.53, 1.49, 1.48, 1.56,
#        1.62, 1.63, 1.46, 1.51, 1.61, 1.47, 1.66, 1.57, 1.6 , 1.5 , 1.68,
#        1.54, 1.64, 1.58,  nan])

# %% [markdown]
# we can observe that Average Price has continous data.

# %% [markdown]
# # Checking Null Values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      14951
# Date            14951
# AveragePrice    14951
# Total Volume    14951
# 4046            14951
# 4225            14951
# 4770            14951
# Total Bags      14951
# Small Bags      14951
# Large Bags      14951
# XLarge Bags     14951
# type            14951
# year            14951
# region          14951
# dtype: int64

# %% [markdown]
# Since the Dataset many null values we are going to drop them since they are not going to be useful in analysing our average price per product.

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# We have dropped the null value columns since huge datas in the column are missing and replacing them with mean or median will get into giving
# dummy values.

# %% [markdown]
# # Visualization of the Data

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Statistical Analysis

# %%
df.describe()
# Out:
#         Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# ...

# %% [markdown]
# # Correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#               Unnamed: 0  AveragePrice  Total Volume      4046      4225  \
# Unnamed: 0      1.000000     -0.075531      0.091934  0.092013  0.093566
# AveragePrice   -0.075531      1.000000     -0.140470 -0.190096 -0.092084
# Total Volume    0.091934     -0.140470      1.000000  0.985568  0.987154
# 4046            0.092013     -0.190096      0.985568  1.000000  0.951952
# 4225            0.093566     -0.092084      0.987154  0.951952  1.000000
# 4770            0.075647     -0.100567      0.934347  0.898570  0.927757
# Total Bags      0.081007     -0.111597      0.967689  0.930395  0.951779
# Small Bags      0.083485     -0.097682      0.960642  0.922278  0.943988
# Large Bags      0.065364     -0.177480      0.910226  0.884229  0.900496
# XLarge Bags    -0.050993     -0.048284      0.521717  0.474063  0.504718
# year           -0.012854      0.178683     -0.004189 -0.040439 -0.007254
#
#                   4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# ...

# %%
sns.heatmap(dfcor)
# Out:
# <AxesSubplot:>

# %%
corr = df.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
df_x =df.drop(["AveragePrice"],axis =1)

# %%
df_x.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
len(df)
# Out:
# 1517

# %%
df_x.head()
# Out:
#    Unnamed: 0        Date  Total Volume     4046       4225    4770  \
# 0         0.0  27-12-2015      64236.62  1036.74   54454.85   48.16
# 1         1.0  20-12-2015      54876.98   674.28   44638.81   58.33
# 2         2.0  13-12-2015     118220.22   794.70  109149.67  130.50
# 3         3.0  06-12-2015      78992.15  1132.00   71976.41   72.58
# 4         4.0  29-11-2015      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type    year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015.0
# 1     9505.56     9408.07       97.49          0.0  conventional  2015.0
# 2     8145.35     8042.21      103.14          0.0  conventional  2015.0
# 3     5811.16     5677.40      133.76          0.0  conventional  2015.0
# 4     6183.95     5986.26      197.69          0.0  conventional  2015.0
#
#    region
# 0  Albany
# 1  Albany
# 2  Albany
# 3  Albany
# 4  Albany

# %%
y = df["AveragePrice"]

# %%
y.shape
# Out:
# (1517,)

# %%
df_x.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
df_x = df_x.drop(['Unnamed: 0','Date'],axis = 1)

# %%
df_x.head()
# Out:
#    Total Volume     4046       4225    4770  Total Bags  Small Bags  \
# 0      64236.62  1036.74   54454.85   48.16     8696.87     8603.62
# 1      54876.98   674.28   44638.81   58.33     9505.56     9408.07
# 2     118220.22   794.70  109149.67  130.50     8145.35     8042.21
# 3      78992.15  1132.00   71976.41   72.58     5811.16     5677.40
# 4      51039.60   941.48   43838.39   75.78     6183.95     5986.26
#
#    Large Bags  XLarge Bags          type    year  region
# 0       93.25          0.0  conventional  2015.0  Albany
# 1       97.49          0.0  conventional  2015.0  Albany
# 2      103.14          0.0  conventional  2015.0  Albany
# 3      133.76          0.0  conventional  2015.0  Albany
# 4      197.69          0.0  conventional  2015.0  Albany

# %%
df_cat = df_x[['type', 'year','region']]

# %%
df_cat.head()
# Out:
#            type    year  region
# 0  conventional  2015.0  Albany
# 1  conventional  2015.0  Albany
# 2  conventional  2015.0  Albany
# 3  conventional  2015.0  Albany
# 4  conventional  2015.0  Albany

# %%
df['AveragePrice'].plot.hist()
plt.show()

# %%
df['Total Volume'].plot.hist()
plt.show()

# %%
df['Total Bags'].plot.hist()
plt.show()

# %%
sns.distplot(df['AveragePrice'],bins=10)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
sns.distplot(df['Total Volume'],bins=10)
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Density'>

# %%
sns.distplot(df['Total Bags'],bins=10)
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='Density'>

# %%
df['AveragePrice'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Total Volume'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['Total Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df_x.shape
# Out:
# (1517, 11)

# %%
sns.pairplot(df)

# %%
# year
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df_cat["year"].values)
cat1 = le.transform(df_cat["year"].values)
df_x["year"] = cat1

#type
le = preprocessing.LabelEncoder()
le.fit(df_cat["type"].values)
cat2 = le.transform(df_cat["type"].values)
df_x["type"] = cat2

# region

le = preprocessing.LabelEncoder()
le.fit(df_cat["region"].values)
cat3 = le.transform(df_cat["region"].values)
df_x["region"] = cat3

# %%
df_x.head()
# Out:
#    Total Volume     4046       4225    4770  Total Bags  Small Bags  \
# 0      64236.62  1036.74   54454.85   48.16     8696.87     8603.62
# 1      54876.98   674.28   44638.81   58.33     9505.56     9408.07
# 2     118220.22   794.70  109149.67  130.50     8145.35     8042.21
# 3      78992.15  1132.00   71976.41   72.58     5811.16     5677.40
# 4      51039.60   941.48   43838.39   75.78     6183.95     5986.26
#
#    Large Bags  XLarge Bags  type  year  region
# 0       93.25          0.0     0     0       0
# 1       97.49          0.0     0     0       0
# 2      103.14          0.0     0     0       0
# 3      133.76          0.0     0     0       0
# 4      197.69          0.0     0     0       0

# %%
df_x.columns
# Out:
# Index(['Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags',
#        'Large Bags', 'XLarge Bags', 'type', 'year', 'region'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

scaler.fit(df_x[['Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags','Large Bags', 'XLarge Bags']])
df_n = scaler.transform(df_x[['Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags','Large Bags', 'XLarge Bags']])

# %%
df_n.shape
# Out:
# (1517, 8)

# %%
X = pd.DataFrame(df_n,columns =['Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags','Large Bags', 'XLarge Bags'] )

# %%
X.head()
# Out:
#    Total Volume      4046      4225      4770  Total Bags  Small Bags  \
# 0     -0.346966 -0.331490 -0.333053 -0.365608   -0.375994   -0.371055
# 1     -0.349078 -0.331676 -0.338923 -0.365534   -0.374927   -0.369812
# 2     -0.334785 -0.331614 -0.300348 -0.365010   -0.376722   -0.371922
# 3     -0.343636 -0.331441 -0.322576 -0.365431   -0.379802   -0.375576
# 4     -0.349944 -0.331539 -0.339401 -0.365408   -0.379310   -0.375098
#
#    Large Bags  XLarge Bags
# 0   -0.360044    -0.292727
# 1   -0.360008    -0.292727
# 2   -0.359960    -0.292727
# 3   -0.359701    -0.292727
# 4   -0.359160    -0.292727

# %%
X.describe()
# Out:
#        Total Volume          4046          4225          4770    Total Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean  -7.944279e-17  3.286026e-17  2.638335e-16  6.623282e-17  6.930661e-17
# std    1.000330e+00  1.000330e+00  1.000330e+00  1.000330e+00  1.000330e+00
# min   -3.527168e-01 -3.317824e-01 -3.645481e-01 -3.659578e-01 -3.831007e-01
# 25%   -3.281845e-01 -3.215447e-01 -3.408137e-01 -3.593418e-01 -3.396878e-01
# 50%   -2.705716e-01 -2.900338e-01 -2.946580e-01 -3.101395e-01 -2.898385e-01
# 75%   -1.398801e-01 -1.380915e-01 -7.551458e-02 -1.541951e-01 -1.794681e-01
# max    9.714954e+00  9.392330e+00  1.096959e+01  9.664229e+00  8.502679e+00
#
#          Small Bags    Large Bags   XLarge Bags
# count  1.517000e+03  1.517000e+03  1.517000e+03
# mean  -1.802557e-16  1.190727e-16  1.623107e-15
# std    1.000330e+00  1.000330e+00  1.000330e+00
# min   -3.792304e-01 -3.608329e-01 -2.927273e-01
# ...

# %%
df_x.columns
# Out:
# Index(['Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags',
#        'Large Bags', 'XLarge Bags', 'type', 'year', 'region'],
#       dtype='object')

# %%
X[['type', 'year', 'region']] = df_x[['type', 'year', 'region']]

# %%
X
# Out:
#       Total Volume      4046      4225      4770  Total Bags  Small Bags  \
# 0        -0.346966 -0.331490 -0.333053 -0.365608   -0.375994   -0.371055
# 1        -0.349078 -0.331676 -0.338923 -0.365534   -0.374927   -0.369812
# 2        -0.334785 -0.331614 -0.300348 -0.365010   -0.376722   -0.371922
# 3        -0.343636 -0.331441 -0.322576 -0.365431   -0.379802   -0.375576
# 4        -0.349944 -0.331539 -0.339401 -0.365408   -0.379310   -0.375098
# ...            ...       ...       ...       ...         ...         ...
# 1512     -0.318397 -0.302475 -0.331910 -0.238672   -0.309055   -0.308916
# 1513     -0.321242 -0.309770 -0.334407 -0.224966   -0.303931   -0.299831
# 1514     -0.321203 -0.308209 -0.333987 -0.244443   -0.305099   -0.301950
# 1515     -0.318784 -0.304230 -0.333568 -0.238936   -0.303098   -0.298364
# 1516     -0.320172 -0.309877 -0.333209 -0.245699   -0.296272   -0.295579
#
#       Large Bags  XLarge Bags  type  year  region
# ...

# %% [markdown]
# # Linear Regression

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression(normalize=True)
lr.fit(x_train,y_train)
lr_pred=lr.predict(x_test)

# %%
lr_pred
# Out:
# array([0.96744338, 1.0687769 , 1.09931934, 1.26983867, 1.3224994 ,
#        1.0701003 , 1.0662549 , 1.02174866, 1.16987681, 1.0314352 ,
#        1.13575248, 1.03499834, 1.04792917, 1.09530649, 1.07409081,
#        0.92294332, 1.14240532, 1.04271362, 1.09729781, 1.05335752,
#        1.07448087, 1.13125765, 1.07239778, 1.08755622, 0.98855929,
#        1.07411016, 1.06591445, 1.03116414, 1.10823146, 0.81374601,
#        1.04002009, 1.04757398, 1.10045577, 1.10964135, 1.07119379,
#        0.99356701, 1.03822937, 1.04710917, 0.54357576, 1.06691634,
#        1.12548573, 1.06638493, 1.09665247, 1.06521644, 1.05173001,
#        1.06092443, 0.8979163 , 1.12808139, 1.18051596, 1.06655863,
#        1.27064735, 1.05475378, 1.04679622, 1.05280283, 1.20698038,
#        1.07640601, 0.84098223, 1.13592343, 1.00424157, 1.07903539,
#        1.08578342, 1.14901785, 1.08883192, 1.03975242, 1.05237281,
#        1.1006158 , 1.15034303, 1.05015178, 1.13236889, 1.02972042,
# ...

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, lr_pred)
# Out:
# 0.14011849518175365

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, lr_pred)
# Out:
# 0.033770012289804315

# %% [markdown]
# squaredbool, default=True If True returns MSE value, if False returns RMSE value.

# %%
print("RMSE VALUE = ",mean_squared_error(y_test, lr_pred,squared = False))
# Out:
# RMSE VALUE =  0.1837661891910596

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
import numpy as np
o = np.array(y_test)

# %%
print("original average price is " ,o[0])
print("predicted average price is " , lr_pred[0])
# Out:
# original average price is  1.03
# predicted average price is  0.9674433819175909

# %%
import pickle

filename='pickledfle1.pkl'
pickle.dump(lr, open(filename,'wb'))

#load the model from disk
loaded_model=pickle.load(open(filename,'rb'))
loaded_model.predict(x_test)
# Out:
# array([0.96744338, 1.0687769 , 1.09931934, 1.26983867, 1.3224994 ,
#        1.0701003 , 1.0662549 , 1.02174866, 1.16987681, 1.0314352 ,
#        1.13575248, 1.03499834, 1.04792917, 1.09530649, 1.07409081,
#        0.92294332, 1.14240532, 1.04271362, 1.09729781, 1.05335752,
#        1.07448087, 1.13125765, 1.07239778, 1.08755622, 0.98855929,
#        1.07411016, 1.06591445, 1.03116414, 1.10823146, 0.81374601,
#        1.04002009, 1.04757398, 1.10045577, 1.10964135, 1.07119379,
#        0.99356701, 1.03822937, 1.04710917, 0.54357576, 1.06691634,
#        1.12548573, 1.06638493, 1.09665247, 1.06521644, 1.05173001,
#        1.06092443, 0.8979163 , 1.12808139, 1.18051596, 1.06655863,
#        1.27064735, 1.05475378, 1.04679622, 1.05280283, 1.20698038,
#        1.07640601, 0.84098223, 1.13592343, 1.00424157, 1.07903539,
#        1.08578342, 1.14901785, 1.08883192, 1.03975242, 1.05237281,
#        1.1006158 , 1.15034303, 1.05015178, 1.13236889, 1.02972042,
# ...
